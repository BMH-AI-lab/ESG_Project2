# %%
# %run C:/ESG_Project2/Service/app.py
# Out:
# ❌ Arduino connection failed: could not open port 'COM8': FileNotFoundError(2, '지정된 파일을 찾을 수 없습니다.', None, 2)
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.145:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [04/Feb/2026 09:36:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Feb/2026 09:36:47] "GET /static/home_dark.png HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2026 09:36:48] "GET /static/intro.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2026 09:36:48] "GET /static/scan.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2026 09:36:48] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2026 09:36:48] "GET /static/live.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2026 09:36:48] "GET /static/card_intro.jpg HTTP/1.1" 304 -
# ...
